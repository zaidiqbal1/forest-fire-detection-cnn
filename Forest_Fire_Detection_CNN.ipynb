# %%
# ---------- 0. Prepare environment ----------
# 0.1 Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 0.2 Imports & GPU check
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

print("TensorFlow version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))

# ---------- 1. Paths & quick dataset check ----------
data_dir = "/content/drive/MyDrive/Dataset"   # ← aapka provided path

# Ensure dataset directory exists
if not os.path.exists(data_dir):
    raise FileNotFoundError(f"Dataset path not found: {data_dir}")

# Count images per class (expects subfolders = class names)
print("\nClass folders and image counts:")
for item in sorted(os.listdir(data_dir)):
    p = os.path.join(data_dir, item)
    if os.path.isdir(p):
        count = sum(len(files) for _,_,files in os.walk(p))
        print(f"  {item}: {count}")
print()

# ---------- 2. Parameters ----------
img_size = (128, 128)    # speed vs accuracy: change to 224 for larger models
batch_size = 32
seed = 123
validation_split = 0.2
epochs = 15

# ---------- 3. Create train / validation datasets ----------
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=validation_split,
    subset="training",
    seed=seed,
    image_size=img_size,
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=validation_split,
    subset="validation",
    seed=seed,
    image_size=img_size,
    batch_size=batch_size
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Detected classes:", class_names)
print("Number of classes:", num_classes)

# ---------- 4. Visualize a few training images (sanity check) ----------
plt.figure(figsize=(8,8))
for images, labels in train_ds.take(1):
    for i in range(min(9, images.shape[0])):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[int(labels[i])])
        plt.axis("off")
plt.show()

# ---------- 5. Performance: prefetch ----------
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# ---------- 6. Data augmentation (applied inside model) ----------
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.08),
])

# ---------- 7. Build the CNN model ----------
model = keras.Sequential([
    layers.Rescaling(1./255, input_shape=(img_size[0], img_size[1], 3)),
    data_augmentation,

    layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    layers.MaxPooling2D(),

    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.MaxPooling2D(),

    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')   # <-- softmax as requested
])

# ---------- 8. Compile (Adam lr=0.001) ----------
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',   # suitable for integer labels
              metrics=['accuracy'])

model.summary()

# ---------- 9. Callbacks ----------
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

checkpoint_path = "/content/drive/MyDrive/forest_fire_best.h5"
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
    ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
]

# ---------- 10. Train ----------
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=callbacks
)

# ---------- 11. Evaluate ----------
loss, acc = model.evaluate(val_ds)
print(f"\nValidation Loss: {loss:.4f}, Validation Accuracy: {acc*100:.2f}%")

# ---------- 12. Plot accuracy & loss ----------
acc_history = history.history.get('accuracy', [])
val_acc_history = history.history.get('val_accuracy', [])
loss_history = history.history.get('loss', [])
val_loss_history = history.history.get('val_loss', [])

epochs_range = range(1, len(acc_history) + 1)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(epochs_range, acc_history, label='train_acc')
plt.plot(epochs_range, val_acc_history, label='val_acc')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs_range, loss_history, label='train_loss')
plt.plot(epochs_range, val_loss_history, label='val_loss')
plt.title('Loss')
plt.legend()
plt.show()

# ---------- 13. Save final model ----------
final_model_path = "/content/drive/MyDrive/forest_fire_final.h5"
model.save(final_model_path)
print("Model saved to:", final_model_path)

# ---------- 14. Inference example (single image) ----------
# Replace <class_folder> and <image_name.jpg> with an actual path to test
# img_path = "/content/drive/MyDrive/Dataset/<class_folder>/<image_name.jpg>"
# from tensorflow.keras.preprocessing import image
# img = image.load_img(img_path, target_size=img_size)
# x = image.img_to_array(img)
# x = np.expand_dims(x, axis=0) / 255.0
# preds = model.predict(x)
# print("Probabilities:", preds)
# print("Predicted class:", class_names[np.argmax(preds)])

# ---------- 15. Optional: Confusion matrix & classification report ----------
# (Uncomment below if sklearn is available and dataset not too large)
# import sklearn
# from sklearn.metrics import classification_report, confusion_matrix
# y_true = np.concatenate([y.numpy() for x,y in val_ds], axis=0)
# y_probs = model.predict(val_ds)
# y_pred = np.argmax(y_probs, axis=1)
# print(classification_report(y_true, y_pred, target_names=class_names))
# print(confusion_matrix(y_true, y_pred))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:82: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(
# TensorFlow version: 2.20.0
# GPUs: []
#
# Class folders and image counts:
#   test_big: 2007
#   test_small: 25
#   train-smoke: 12631
#   train_fire: 1101
#
# Found 15764 files belonging to 4 classes.
# Using 12612 files for training.
# Found 15764 files belonging to 4 classes.
# Using 3152 files for validation.
# Detected classes: ['test_big', 'test_small', 'train-smoke', 'train_fire']
# Number of classes: 4
# ...

# %%
# %pip install tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.7/620.7 MB 738.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 108.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 143.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 143.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.3 MB/s eta 0:00:00
# ...
